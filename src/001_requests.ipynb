# %%
# Install dependencies
# %pip install anthropic python-dotenv

# %%
# Load Env Variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create API Client
from anthropic import Anthropic
client = Anthropic()
model = "claude-haiku-4-5" # fastest model, but also least capable. For more capable models, see https://docs.anthropic.com/claude/reference/models

# %%
# Create Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)
# Out:
# C:\Users\spampolini\AppData\Local\Temp\ipykernel_16412\910959703.py:11: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = client.messages.create(

# %%
final_answer
# Out:
# 'Unlike classical computers that process information using bits that are either 0 or 1, quantum computers leverage the strange properties of quantum physics to perform many calculations in parallel, making them particularly promising for applications like cryptography, drug discovery, and optimization problems.'
