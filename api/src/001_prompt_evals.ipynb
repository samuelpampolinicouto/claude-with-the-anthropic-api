# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
test_dataset = generate_dataset()
with open("eval_dataset.json", "w") as f:
    f.write(test_dataset)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("eval_dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 URI Parser\n\nHere's a clean and robust solution:\n\n```python\ndef parse_s3_uri(uri: str) -> dict:\n    \"\"\"\n    Parse an AWS S3 bucket URI and return bucket name and object key.\n    \n    Args:\n        uri (str): S3 URI in the format 's3://bucket-name/path/to/object'\n    \n    Returns:\n        dict: Dictionary with 'bucket' and 'key' keys\n    \n    Raises:\n        ValueError: If the URI format is invalid\n    \n    Example:\n        >>> parse_s3_uri('s3://my-bucket/path/to/object')\n        {'bucket': 'my-bucket', 'key': 'path/to/object'}\n    \"\"\"\n    # Validate the URI format\n    if not uri.startswith('s3://'):\n        raise ValueError(f\"Invalid S3 URI: {uri}. Must start with 's3://'\")\n    \n    # Remove the 's3://' prefix\n    uri_without_prefix = uri[5:]\n    \n    # Find the first '/' to separate bucket from key\n    slash_index = uri_without_prefix.find('/')\n    \n    if slash_index == -1:\n        # No key provided, only bucket name\n        bucket = uri_without_prefix\n        key = ''\n    else:\n        bucket = uri_without_prefix[:slash_index]\n        key = uri_without_prefix[slash_index + 1:]\n    \n    # Validate bucket name is not empty\n    if not bucket:\n        raise ValueError(f\"Invalid S3 URI: {uri}. Bucket name cannot be empty\")\n    \n    return {'bucket': bucket, 'key': key}\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Test 1: Standard S3 URI with path\n    result1 = parse_s3_uri('s3://my-bucket/path/to/object')\n    print(f\"Test 1: {result1}\")\n    assert result1 == {'bucket': 'my-bucket', 'key': 'path/to/object'}\n    \n    # Test 2: S3 URI with only bucket\n    result2 = parse_s3_uri('s3://my-bucket')\n    print(f\"Test 2: {result2}\")\n    assert result2 == {'bucket': 'my-bucket', 'key': ''}\n    \n    # Test 3: S3 URI with trailing slash\n    result3 = parse_s3_uri('s3://my-bucket/')\n    print(f\"Test 3: {result3}\")\n    assert result3 == {'bucket': 'my-bucket', 'key': ''}\n    \n    # Test 4: S3 URI with complex path\n    result4 = parse_s3_uri('s3://bucket-name/folder/subfolder/file.txt')\n    print(f\"Test 4: {result4}\")\n    assert result4 == {'bucket': 'bucket-name', 'key': 'folder/subfolder/file.txt'}\n    \n    # Test 5: Invalid URI (no s3:// prefix)\n    try:\n        parse_s3_uri('http://my-bucket/path')\n        print(\"Test 5: FAILED - Should have raised ValueError\")\n    except ValueError as e:\n        print(f\"Test 5: Correctly raised ValueError - {e}\")\n    \n    # Test 6: Invalid URI (empty bucket)\n    try:\n        parse_s3_uri('s3:///path/to/object')\n        print(\"Test 6: FAILED - Should have raised ValueError\")\n    except ValueError as e:\n        print(f\"Test 6: Correctly raised ValueError - {e}\")\n    \n    print(\"\\nAll tests passed!\")\n```\n\n## Alternative Solution Using `urllib.parse`\n\nIf you prefer a more robust approach using Python's built-in libraries:\n\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_uri(uri: str) -> dict:\n    \"\"\"\n    Parse an AWS S3 bucket URI using urllib.parse.\n    \n    Args:\n        uri (str):",
#     "test_case": {
#       "task": "Write a Python function that parses an AWS S3 bucket URI (e.g., 's3://my-bucket/path/to/object') and returns a dictionary with keys 'bucket' and 'key'"
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Read-Only S3 Bucket Policy\n\nHere's a JSON object for read-only access to the 'data-lake' S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListDataLakeBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketLocation\"\n      ],\n      \"Resource\": \"arn:aws:s3:::data-lake\"\n    },\n    {\n      \"Sid\": \"ReadDataLakeObjects\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::data-lake/*\"\n    }\n  ]\n}\n```\n\n## Explanation\n\n| Component | Purpose |\n|-----------|---------|\n| **Version** | Policy language version (always use \"2012-10-17\") |\n| **Statement 1** | Allows listing bucket contents and getting bucket info |\n| **Statement 2** | Allows retrieving objects and their versions |\n| **Resource** | ARNs pointing to the bucket and its objects |\n\n## Permissions Included\n\n- \u2705 **s3:ListBucket** - List objects in the bucket\n- \u2705 **s3:GetBucketLocation** - Get bucket region information\n- \u2705 **s3:GetObject** - Download/read objects\n- \u2705 **s3:GetObjectVersion** - Access object versions\n\n## Permissions Excluded\n\n- \u274c No write permissions (PutObject, DeleteObject, etc.)\n- \u274c No bucket modification permissions\n- \u274c No IAM or policy management permissions\n\nThis policy follows the principle of least privilege for read-only access.",
#     "test_case": {
#       "task": "Create a JSON object representing an AWS IAM policy that allows read-only access to all objects in a specific S3 bucket named 'data-lake'"
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regex\n\nHere's the regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Breakdown\n\n| Part | Meaning |\n|------|---------|\n| `^` | Start of string |\n| `i-` | Literal characters 'i' and hyphen |\n| `[0-9a-f]` | Single hexadecimal character (0-9, a-f) |\n| `{17}` | Exactly 17 of the preceding pattern |\n| `$` | End of string |\n\n## Examples\n\n**Valid matches:**\n- `i-0a1b2c3d4e5f6g7h8` \u274c (contains 'g', not hex)\n- `i-0a1b2c3d4e5f6a7b8` \u2705\n- `i-1234567890abcdef0` \u2705\n\n**Invalid matches:**\n- `i-0a1b2c3d4e5f6a7b` \u274c (only 16 hex chars)\n- `i-0a1b2c3d4e5f6a7b8j` \u274c (18 hex chars, contains 'j')\n- `0a1b2c3d4e5f6a7b8` \u274c (missing 'i-' prefix)\n\n## Case-Insensitive Variant\n\nIf you need to match uppercase hexadecimal characters as well:\n\n```regex\n^i-[0-9a-fA-F]{17}$\n```\n\nOr with the case-insensitive flag (varies by language):\n```regex\n^i-[0-9a-f]{17}$  (with /i flag)\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: 'i-' followed by 17 hexadecimal characters)"
#     },
#     "score": 10
#   }
# ]
